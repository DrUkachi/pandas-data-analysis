# %%
import pandas as pd
import os

# %%
#os.rename('C:\\Users\\Ukachi\\Documents\\eHealth4Everyone\\Data Analysis Course\\used-cars-price-prediction\\train-data', 'C:\\Users\\Ukachi\\Documents\\eHealth4Everyone\\Data Analysis Course\\used-cars-price-prediction\\train-data.csv')
car_data = pd.read_csv(open('C:\\Users\\Ukachi\\Documents\\eHealth4Everyone\\Data Analysis Course\\used-cars-price-prediction\\train-data.csv','rb'), index_col=0)

car_data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
loan_data = pd.read_csv(open('C:\\Users\\Ukachi\\Documents\\eHealth4Everyone\\Data Analysis Course\\train_data.csv','rb'), index_col=0)
loan_data.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# ...

# %% [markdown]
# # Simple Dataframe Operations
#  To access these columns we do this loan_data["Education"] or loan["ApplicantIncome"]

# %%
 loan_data["ApplicantIncome"] = loan_data["ApplicantIncome"] / 1000

# %%
loan_data.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002            5.849                0.0         NaN             360.0
# LP001003            4.583             1508.0       128.0             360.0
# LP001005            3.000                0.0        66.0             360.0
# LP001006            2.583             2358.0       120.0             360.0
# LP001008            6.000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# ...

# %%
'C:\\Users\\Ukachi\\Documents\\eHealth4Everyone\\Data Analysis Course\\train_data.csv'

# %%
load_data

# %%
2**
